# %% [markdown]
# # 이동평균선을 이용한 Simple trading strategy
#
# - fast signal (단기 이동평균) 이 slow signal (장기 이동평균)위에 있으면 1 주 보유, 아래에 있으면 0 주 보유 전략
# - 종가에 매수, 매도 한다고 가정. 거래비용 없다고 가정.
#
# - MA10 >= MA50 : 1 주 보유 (매수 or hold), MA10 < MA50 : 0 주 보유 (매도 or no action)
#
# - Daily Profit 계산
#
# - 누적 수익 계산

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import pandas_datareader as data_reader

short = 10
long = 50  # 100, 200

# %%
ms = data_reader.DataReader("MSFT", data_source="yahoo")  #Microsoft
ms.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-08-02  72.559998  71.440002  72.550003  72.260002  26499200.0  67.682610
# 2017-08-03  72.440002  71.849998  72.190002  72.150002  18214400.0  67.579590
# 2017-08-04  73.040001  72.239998  72.400002  72.680000  22579000.0  68.076027
# 2017-08-07  72.900002  72.260002  72.800003  72.400002  18705700.0  67.813736
# 2017-08-08  73.129997  71.750000  72.089996  72.790001  22044600.0  68.179054

# %%
ms.drop(['High', 'Low', 'Open', 'Volume', 'Close'], axis=1, inplace=True)

# %%
ms['MA_SHORT'] = ms['Adj Close'].rolling(short).mean()
ms['MA_LONG'] = ms['Adj Close'].rolling(long).mean()
ms['Shares'] = [1 if ms.loc[day, 'MA_SHORT'] >= ms.loc[day, 'MA_LONG'] else 0 for day in ms.index]
ms.head()
# Out:
#             Adj Close  MA_SHORT  MA_LONG  Shares
# Date
# 2017-08-02  67.682610       NaN      NaN       0
# 2017-08-03  67.579590       NaN      NaN       0
# 2017-08-04  68.076027       NaN      NaN       0
# 2017-08-07  67.813736       NaN      NaN       0
# 2017-08-08  68.179054       NaN      NaN       0

# %%
ms['NextDay Close'] = ms['Adj Close'].shift(-1)
ms.head()
# Out:
#             Adj Close  MA_SHORT  MA_LONG  Shares  NextDay Close
# Date
# 2017-08-02  67.682610       NaN      NaN       0      67.579590
# 2017-08-03  67.579590       NaN      NaN       0      68.076027
# 2017-08-04  68.076027       NaN      NaN       0      67.813736
# 2017-08-07  67.813736       NaN      NaN       0      68.179054
# 2017-08-08  68.179054       NaN      NaN       0      67.879303

# %%
ms[['MA_SHORT', 'MA_LONG']].plot(figsize=(12, 6))
plt.title(f"short = {short}, long = {long}")
# Out:
# Text(0.5, 1.0, 'short = 10, long = 50')

# %% [markdown]
# ## Daily Profit

# %%
# Daily Profit 계산
ms['Profit'] = [ms.loc[day, 'NextDay Close'] - ms.loc[day, 'Adj Close'] 
                if ms.loc[day, 'Shares'] == 1 else 0 for day in ms.index]

ms.iloc[100:105]
# Out:
#             Adj Close   MA_SHORT    MA_LONG  Shares  NextDay Close    Profit
# Date
# 2017-12-22  80.924385  81.051192  78.256124       1      80.820290 -0.104095
# 2017-12-26  80.820290  81.067281  78.413169       1      81.113655  0.293365
# 2017-12-27  81.113655  81.079585  78.573069       1      81.123123  0.009468
# 2017-12-28  81.123123  81.114601  78.734288       1      80.952759 -0.170364
# 2017-12-29  80.952759  81.195042  78.891723       1      81.340767  0.388008

# %%
ms['Profit'].min(), ms['Profit'].max(), ms['Profit'].mean()
# Out:
# (-14.131332397460938, 12.979034423828125, 0.07331632676348386)

# %%
# red line 위쪽은 make money 아래는 lose money
ms['Profit'].plot()
plt.axhline(y=0, color='r')

# %% [markdown]
# ## 누적 수익

# %%
ms['wealth'] = ms['Profit'].cumsum()
ms.tail()
# Out:
#              Adj Close    MA_SHORT     MA_LONG  Shares  NextDay Close  \
# Date
# 2022-07-26  251.899994  257.549995  260.180911       0     268.739990
# 2022-07-27  268.739990  259.151994  260.345446       0     276.410004
# 2022-07-28  276.410004  261.384995  260.655799       1     280.739990
# 2022-07-29  280.739990  263.786993  260.946598       1     278.010010
# 2022-08-01  278.010010  266.162994  261.425198       1            NaN
#
#               Profit     wealth
# Date
# 2022-07-26  0.000000  90.558617
# 2022-07-27  0.000000  90.558617
# 2022-07-28  4.329987  94.888603
# 2022-07-29 -2.729980  92.158623
# 2022-08-01       NaN        NaN

# %%
n_days = len(pd.date_range(ms.index[0], ms.index[-1]))

print('MA_SHORT >= MA_LONG : 1 주 보유 (매수 or hold), MA_SHORT < MA_LONG : 0 주 보유 ')
print(f"이 전략으로 {n_days}일 동안 1주 매매로 얻은 수익 : {ms.loc[ms.index[-2], 'wealth']:.2f} ")

ms[['Adj Close', 'MA_SHORT', 'MA_LONG', 'wealth']].plot(figsize=(16, 10))
plt.title(f"short = {short}, long = {long}")
# Out:
# MA_SHORT >= MA_LONG : 1 주 보유 (매수 or hold), MA_SHORT < MA_LONG : 0 주 보유
# 이 전략으로 1826일 동안 1주 매매로 얻은 수익 : 92.16
# Text(0.5, 1.0, 'short = 10, long = 50')
