# %% [markdown]
# # 이동평균선을 이용한 Simple trading strategy
#
# - fast signal (단기 이동평균) 이 slow signal (장기 이동평균)위에 있으면 1 주 보유, 아래에 있으면 0 주 보유 전략
# - 종가에 매수, 매도 한다고 가정. 거래비용 없다고 가정.
#
# - MA10 >= MA50 : 1 주 보유 (매수 or hold), MA10 < MA50 : 0 주 보유 (매도 or no action)
#
# - Daily Profit 계산
#
# - 누적 수익 계산

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import pandas_datareader as data_reader

short = 10
long = 50  # 100, 200

# %%
ms = data_reader.DataReader("MSFT", data_source="yahoo")  #Microsoft
ms.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-08-09  72.510002  72.050003  72.250000  72.470001  22213400.0  67.879303
# 2017-08-10  72.190002  71.349998  71.900002  71.410004  24734500.0  66.886475
# 2017-08-11  72.699997  71.279999  71.610001  72.500000  21443700.0  67.907402
# 2017-08-14  73.720001  72.949997  73.059998  73.589996  20096600.0  68.928329
# 2017-08-15  73.589996  73.040001  73.589996  73.220001  19181400.0  68.947197

# %%
ms.drop(['High', 'Low', 'Open', 'Volume', 'Close'], axis=1, inplace=True)

# %%
ms['MA_SHORT'] = ms['Adj Close'].rolling(short).mean()
ms['MA_LONG'] = ms['Adj Close'].rolling(long).mean()
ms['Shares'] = [1 if ms.loc[day, 'MA_SHORT'] >= ms.loc[day, 'MA_LONG'] 
                else 0 for day in ms.index]
ms.head()
# Out:
#             Adj Close  MA_SHORT  MA_LONG  Shares
# Date
# 2017-08-09  67.879303       NaN      NaN       0
# 2017-08-10  66.886475       NaN      NaN       0
# 2017-08-11  67.907402       NaN      NaN       0
# 2017-08-14  68.928329       NaN      NaN       0
# 2017-08-15  68.947197       NaN      NaN       0

# %%
ms.tail()
# Out:
#              Adj Close    MA_SHORT     MA_LONG  Shares
# Date
# 2022-08-02  274.820007  267.691995  261.858799       1
# 2022-08-03  282.470001  269.711996  262.456999       1
# 2022-08-04  283.649994  271.592996  262.916999       1
# 2022-08-05  282.910004  273.847998  263.382799       1
# 2022-08-08  280.320007  275.997000  263.738799       1

# %%
ms['NextDay Close'] = ms['Adj Close'].shift(-1)
ms.head()
# Out:
#             Adj Close  MA_SHORT  MA_LONG  Shares  NextDay Close
# Date
# 2017-08-09  67.879303       NaN      NaN       0      66.886475
# 2017-08-10  66.886475       NaN      NaN       0      67.907402
# 2017-08-11  67.907402       NaN      NaN       0      68.928329
# 2017-08-14  68.928329       NaN      NaN       0      68.947197
# 2017-08-15  68.947197       NaN      NaN       0      69.352104

# %%
ms[['MA_SHORT', 'MA_LONG']].plot(figsize=(12, 6))
plt.title(f"short = {short}, long = {long}")
# Out:
# Text(0.5, 1.0, 'short = 10, long = 50')

# %% [markdown]
# ## Daily Profit

# %%
# Daily Profit 계산
ms['Profit'] = [ms.loc[day, 'NextDay Close'] - ms.loc[day, 'Adj Close'] 
                if ms.loc[day, 'Shares'] == 1 else 0 for day in ms.index]

ms.iloc[100:105]
# Out:
#             Adj Close   MA_SHORT    MA_LONG  Shares  NextDay Close    Profit
# Date
# 2018-01-02  81.340767  81.109865  79.051269       1      81.719337  0.378571
# 2018-01-03  81.719337  81.107027  79.201436       1      82.438568  0.719231
# 2018-01-04  82.438568  81.228163  79.365612       1      83.460655  1.022087
# 2018-01-05  83.460655  81.480845  79.549663       1      83.545830  0.085175
# 2018-01-08  83.545830  81.743937  79.739750       1      83.489052 -0.056778

# %%
ms['Profit'].min(), ms['Profit'].max(), ms['Profit'].mean()
# Out:
# (-14.131332397460938, 12.979034423828125, 0.07426251128446326)

# %%
# red line 위쪽은 make money 아래는 lose money
ms['Profit'].plot()
plt.axhline(y=0, color='r')

# %% [markdown]
# ## 누적 수익

# %%
ms['wealth'] = ms['Profit'].cumsum()
ms.tail()
# Out:
#              Adj Close    MA_SHORT     MA_LONG  Shares  NextDay Close  \
# Date
# 2022-08-02  274.820007  267.691995  261.858799       1     282.470001
# 2022-08-03  282.470001  269.711996  262.456999       1     283.649994
# 2022-08-04  283.649994  271.592996  262.916999       1     282.910004
# 2022-08-05  282.910004  273.847998  263.382799       1     280.320007
# 2022-08-08  280.320007  275.997000  263.738799       1            NaN
#
#               Profit     wealth
# Date
# 2022-08-02  7.649994  95.497971
# 2022-08-03  1.179993  96.677963
# 2022-08-04 -0.739990  95.937973
# 2022-08-05 -2.589996  93.347977
# 2022-08-08       NaN        NaN

# %%
n_days = len(pd.date_range(ms.index[0], ms.index[-1]))

print('MA_SHORT >= MA_LONG : 1 주 보유 (매수 or hold), MA_SHORT < MA_LONG : 0 주 보유 ')
print(f"이 전략으로 {n_days}일 동안 1주 매매로 얻은 수익 : {ms.loc[ms.index[-2], 'wealth']:.2f} ")

ms[['Adj Close', 'MA_SHORT', 'MA_LONG', 'wealth']].plot(figsize=(16, 10))
plt.title(f"short = {short}, long = {long}")
plt.grid()
# Out:
# MA_SHORT >= MA_LONG : 1 주 보유 (매수 or hold), MA_SHORT < MA_LONG : 0 주 보유
# 이 전략으로 1826일 동안 1주 매매로 얻은 수익 : 93.35
