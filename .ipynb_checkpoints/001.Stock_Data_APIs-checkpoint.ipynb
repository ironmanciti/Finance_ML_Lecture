# %% [markdown]
# # Free stock market APIs
#
# 주식 시장 데이터 API는 현재 시장에서 거래되는 금융 자산에 대한 실시간 또는 과거 데이터를 제공합니다. 이러한 API는 일반적으로 공개 주식, ETF, ETN의 가격을 제공합니다.
# 이러한 데이터는 거래 전략을 수립하고 시장을 모니터링하는 기반이 되는 기술 지표를 생성하는 데 사용할 수 있습니다.

# %% [markdown]
# # 1. 야후 파이낸스
# 문서: [yfinance](https://github.com/ranaroussi/yfinance)
# tutorial: https://aroussi.com/post/python-yahoo-finance

# %%
import matplotlib.pyplot as plt

# %%
# !pip install -q yfinance
import yfinance as yf

# %% [markdown]
# - 미국 주식

# %%
df = yf.download('AAPL', start='2022-01-01', progress=False)
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-09-09  220.820007  221.270004  216.710007  220.910004  220.910004
# 2024-09-10  218.919998  221.479996  216.729996  220.110001  220.110001
# 2024-09-11  221.460007  223.089996  217.889999  222.660004  222.660004
# 2024-09-12  222.500000  223.550003  219.820007  222.770004  222.770004
# 2024-09-13  223.580002  224.039993  221.910004  222.500000  222.500000
#
#               Volume
# Date
# 2024-09-09  67180000
# 2024-09-10  51591000
# 2024-09-11  44587100
# 2024-09-12  37498200
# 2024-09-13  36722900

# %% [markdown]
# - 한국 주식

# %%
df = yf.download('005930.KS', start='2022-01-01', progress=False) #삼성전자
df.tail()
# Out:
#                Open     High      Low    Close  Adj Close    Volume
# Date
# 2024-09-09  66900.0  68200.0  66600.0  67500.0    67500.0  23263298
# 2024-09-10  67000.0  67300.0  66000.0  66200.0    66200.0  30651376
# 2024-09-11  65100.0  65500.0  64200.0  64900.0    64900.0  35809707
# 2024-09-12  66000.0  66600.0  65200.0  66300.0    66300.0  35884106
# 2024-09-13  65000.0  65500.0  64300.0  64400.0    64400.0  25045135

# %% [markdown]
# # 2. Pandas data_reader & FinanceDataReader
#
# [pandas-datareader](https://github.com/pydata/pandas-datareader)는 잘 구성된 시계열 데이터 수집 라이브러리로 사용이 간편하고 다양한 시계열 데이터를 수집할 수 있다는 장점이 있다. 하지만, 거래소별(KRX, NASDAQ, NYSE 등) 전체 종목 코드(ticker symbol)를 가져오는 기능이 없으며, 야후 파이낸스가 더 이상지원되지 않고(deprecated), 구글 파이낸스는 UNSTABLE_WARNING + RemoteDataError 를 낸다.
#
# [FinanceDataReader](https://github.com/FinanceData/FinanceDataReader)는 pandas-datareader 를 대체하기 보다 보완하기 위한 목적으로 만들어졌다. 주요한 기능은 다음과 같다.
#
# - 종목 코드
# 거래소별 전체 종목코드: KRX (KOSPI, KODAQ, KONEX), NASDAQ, NYSE, AMEX, S&P 500
#
#
# - 가격 데이터
# 해외주식 가격 데이터: AAPL(애플), AMZN(아마존), GOOG(구글) 등
# 국내주식 가격 데이터: 005930(삼성전자), 091990(셀트리온헬스케어) 등
# 각종 지수: KS11(코스피지수), KQ11(코스닥지수), DJI(다우지수), IXIC(나스닥 지수), US500(S&P 5000)
# 환율 데이터: USD/KRX (원달러 환율), USD/EUR(달러당 유로화 환율), CNY/KRW: 위엔화 원화 환율
# 암호화폐 가격: BTC/USD (비트코인 달러 가격, Bitfinex), BTC/KRW (비트코인 원화 가격, 빗썸)

# %%
# !pip install --upgrade pandas-datareader
# !pip install --upgrade finance-datareader

# %%
import pandas_datareader as data_reader
import FinanceDataReader as fdr
import datetime

start = datetime.datetime(2020, 2, 19)
end = datetime.datetime(2022, 3, 4)

# %% [markdown]
# - 미국 주식

# %%
stock = fdr.DataReader('AAPL' , start=start, end=end)  #APPLE 주식
stock.head()
# Out:
#                  Open       High        Low      Close     Volume  Adj Close
# 2020-02-18  78.839996  79.937500  78.652496  79.750000  152531200  77.584999
# 2020-02-19  80.000000  81.142502  80.000000  80.904999   93984000  78.708633
# 2020-02-20  80.657501  81.162498  79.552498  80.074997  100566000  77.901161
# 2020-02-21  79.654999  80.112503  77.625000  78.262497  129554000  76.137878
# 2020-02-24  74.315002  76.044998  72.307503  74.544998  222195200  72.521294

# %% [markdown]
# - 한국 주식

# %%
stock = fdr.DataReader('005930', start=start, end=end)  # 삼성전자
stock.head()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2020-02-19  59800  60400  59400  60200  12951496  0.006689
# 2020-02-20  60700  61300  59600  60000  14591924 -0.003322
# 2020-02-21  58800  59800  58500  59200  13777393 -0.013333
# 2020-02-24  57400  58100  56800  56800  25627537 -0.040541
# 2020-02-25  56200  58000  56200  57900  23885408  0.019366

# %% [markdown]
# - 원-달러 환율

# %%
df = data_reader.DataReader('DEXKOUS', 'fred', '2022-01-01')
df.head()
# Out:
#             DEXKOUS
# DATE
# 2022-01-03  1191.39
# 2022-01-04  1193.77
# 2022-01-05  1196.38
# 2022-01-06  1205.02
# 2022-01-07  1200.78

# %%
df.tail()
# Out:
#             DEXKOUS
# DATE
# 2024-09-02      NaN
# 2024-09-03  1339.79
# 2024-09-04  1336.93
# 2024-09-05  1335.14
# 2024-09-06  1335.68

# %%
df.plot()
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# - DataReader

# %%
stock = fdr.DataReader("068270", start)
stock
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2020-02-19  172685  173614  167116  168510  795819 -0.016264
# 2020-02-20  168972  169436  163866  166189  811278 -0.013774
# 2020-02-21  163866  168043  163402  164332  483376 -0.011174
# 2020-02-24  160152  162008  156903  156905  827926 -0.045195
# 2020-02-25  156903  160616  156439  160154  612785  0.020707
# ...            ...     ...     ...     ...     ...       ...
# 2024-09-09  186800  193400  186700  192100  399370  0.004707
# 2024-09-10  194200  196400  192400  195800  549128  0.019261
# 2024-09-11  196900  196900  188700  190700  585601 -0.026047
# 2024-09-12  191100  196000  190700  195600  660266  0.025695
# 2024-09-13  195600  196100  193800  195200  285544 -0.002045
#
# [1130 rows x 6 columns]

# %%
stock["Close"].plot()
# Out:
# <Axes: xlabel='Date'>
