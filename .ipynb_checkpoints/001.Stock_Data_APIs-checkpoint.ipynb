# %% [markdown]
# # Free stock market APIs
#
# 주식 시장 데이터 API는 현재 시장에서 거래되는 금융 자산에 대한 실시간 또는 과거 데이터를 제공합니다. 이러한 API는 일반적으로 공개 주식, ETF, ETN의 가격을 제공합니다.
# 이러한 데이터는 거래 전략을 수립하고 시장을 모니터링하는 기반이 되는 기술 지표를 생성하는 데 사용할 수 있습니다.

# %% [markdown]
# # 1. 야후 파이낸스
# 문서: [yfinance](https://github.com/ranaroussi/yfinance)
# tutorial: https://aroussi.com/post/python-yahoo-finance

# %%
import matplotlib.pyplot as plt

# %%
# !pip install -q yfinance

# %% [markdown]
# - 미국 주식

# %%
import yfinance as yf
import datetime

goog = yf.Ticker('goog')
data = goog.history()
data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-09-28 00:00:00-04:00  130.690002  134.179993  130.690002  133.130005
# 2023-09-29 00:00:00-04:00  134.080002  134.889999  131.320007  131.850006
# 2023-10-02 00:00:00-04:00  132.154999  135.360001  132.065002  135.169998
# 2023-10-03 00:00:00-04:00  134.929993  135.240005  132.815002  133.300003
# 2023-10-04 00:00:00-04:00  133.660004  136.570007  133.429993  136.270004
# 2023-10-05 00:00:00-04:00  136.130005  136.500000  134.455002  135.990005
# 2023-10-06 00:00:00-04:00  134.940002  139.186005  134.940002  138.729996
# 2023-10-09 00:00:00-04:00  137.990005  139.970001  136.699997  139.500000
# 2023-10-10 00:00:00-04:00  139.509995  140.740005  138.429993  139.199997
# 2023-10-11 00:00:00-04:00  139.850006  142.220001  139.839996  141.699997
# 2023-10-12 00:00:00-04:00  142.160004  142.380005  139.449997  140.289993
# 2023-10-13 00:00:00-04:00  140.649994  141.339996  137.970001  138.580002
# 2023-10-16 00:00:00-04:00  139.729996  140.904999  139.320007  140.490005
# 2023-10-17 00:00:00-04:00  140.029999  141.250000  138.529007  140.990005
# 2023-10-18 00:00:00-04:00  140.750000  141.990005  138.705002  139.279999
# 2023-10-19 00:00:00-04:00  139.800003  141.005005  138.600006  138.979996
# 2023-10-20 00:00:00-04:00  138.589996  139.039993  136.244995  136.740005
# 2023-10-23 00:00:00-04:00  136.229996  139.020004  135.110001  137.899994
# 2023-10-24 00:00:00-04:00  139.160004  140.710007  138.750000  140.119995
# 2023-10-25 00:00:00-04:00  129.770004  130.100006  126.089996  126.669998
# 2023-10-26 00:00:00-04:00  124.470001  125.459999  122.320000  123.440002
# 2023-10-27 00:00:00-04:00  124.029999  124.440002  121.459999  123.400002
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-09-28 00:00:00-04:00  18201400          0             0
# 2023-09-29 00:00:00-04:00  23224200          0             0
# 2023-10-02 00:00:00-04:00  19210400          0             0
# 2023-10-03 00:00:00-04:00  19628700          0             0
# 2023-10-04 00:00:00-04:00  22848000          0             0
# 2023-10-05 00:00:00-04:00  15922900          0             0
# 2023-10-06 00:00:00-04:00  20819300          0             0
# 2023-10-09 00:00:00-04:00  16599100          0             0
# 2023-10-10 00:00:00-04:00  19554900          0             0
# 2023-10-11 00:00:00-04:00  20146300          0             0
# 2023-10-12 00:00:00-04:00  18173100          0             0
# 2023-10-13 00:00:00-04:00  19438700          0             0
# 2023-10-16 00:00:00-04:00  17345600          0             0
# 2023-10-17 00:00:00-04:00  17424000          0             0
# 2023-10-18 00:00:00-04:00  18304900          0             0
# 2023-10-19 00:00:00-04:00  21831200          0             0
# 2023-10-20 00:00:00-04:00  24953900          0             0
# 2023-10-23 00:00:00-04:00  20780700          0             0
# 2023-10-24 00:00:00-04:00  26535200          0             0
# 2023-10-25 00:00:00-04:00  58796100          0             0
# 2023-10-26 00:00:00-04:00  33907400          0             0
# 2023-10-27 00:00:00-04:00  37349000          0             0

# %%
data = yf.download(['GOOG','META'], start='2021-12-10', end='2021-12-30', group_by='ticker')
data.head()
# Out:
# [*********************100%***********************]  2 of 2 completed
#
# 2 Failed downloads:
# - META: No data found for this date range, symbol may be delisted
# - GOOG: No data found for this date range, symbol may be delisted
# Empty DataFrame
# Columns: [(META, Open), (META, High), (META, Low), (META, Close), (META, Adj Close), (META, Volume), (GOOG, Open), (GOOG, High), (GOOG, Low), (GOOG, Close), (GOOG, Adj Close), (GOOG, Volume)]
# Index: []

# %%
import yfinance as yf
import datetime

# Microsoft (MSFT) 주식을 가져올 기업을 생성합니다.
ticker = yf.Ticker("MSFT")

# 시작 날짜와 종료 날짜를 정의합니다.
start_date = datetime.datetime(2023, 1, 1)
end_date = datetime.datetime(2023, 1, 31)

# 특정 시작 날짜와 종료 날짜로 ticker 주식의 역사적 데이터를 가져옵니다.
hist = ticker.history(start=start_date, end=end_date)

# 가져온 역사적 데이터를 출력합니다.
print(hist)
# Out:
# - MSFT: No data found for this date range, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
ticker = yf.Ticker("MSFT")
# get historical market data
df = ticker.history(start='2022-01-01')
df
# Out:
# - MSFT: No data found for this date range, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
df = yf.download('AAPL', start='2022-01-01', progress=False)
df.tail()
# Out:
# 1 Failed download:
# - AAPL: No data found for this date range, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# - 한국 주식

# %%
df = yf.download('005930.KS', start='2022-01-01', progress=False) #삼성전자
df.tail()
# Out:
# 1 Failed download:
# - 005930.KS: No data found for this date range, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# # 2. FinanceDataReader
#
# - 종목 코드
# 거래소별 전체 종목코드: KRX (KOSPI, KODAQ, KONEX), NASDAQ, NYSE, AMEX, S&P 500
#
#
# - 가격 데이터
# 해외주식 가격 데이터: AAPL(애플), AMZN(아마존), GOOG(구글) 등
# 국내주식 가격 데이터: 005930(삼성전자), 091990(셀트리온헬스케어) 등
# 각종 지수: KS11(코스피지수), KQ11(코스닥지수), DJI(다우지수), IXIC(나스닥 지수), US500(S&P 5000)
# 환율 데이터: USD/KRX (원달러 환율), USD/EUR(달러당 유로화 환율), CNY/KRW: 위엔화 원화 환율
# 암호화폐 가격: BTC/USD (비트코인 달러 가격, Bitfinex), BTC/KRW (비트코인 원화 가격, 빗썸)

# %%
#!pip install finance-datareader

# %%
import FinanceDataReader as fdr
import datetime

start = datetime.datetime(2020, 2, 19)
end = datetime.datetime(2022, 3, 4)

# %% [markdown]
# - 미국 주식

# %%
stock = fdr.DataReader('AAPL', start)  #Apple
stock.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-02-19  80.000000  81.142502  80.000000  80.904999  79.218224   93984000
# 2020-02-20  80.657501  81.162498  79.552498  80.074997  78.405518  100566000
# 2020-02-21  79.654999  80.112503  77.625000  78.262497  76.630814  129554000
# 2020-02-24  74.315002  76.044998  72.307503  74.544998  72.990822  222195200
# 2020-02-25  75.237503  75.632500  71.532501  72.019997  70.518456  230673600

# %%
stock['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# - 한국 주식

# %%
stock = fdr.DataReader('247540', start)  #에코프로
stock.head()
# Out:
#              Open   High    Low  Close   Volume    Change
# Date
# 2020-02-19  21693  21940  20878  21200  3995897  0.005883
# 2020-02-20  21224  22854  20977  22633  6200851  0.067594
# 2020-02-21  22212  22484  21199  21200  4267816 -0.063315
# 2020-02-24  20433  21718  20384  21051  3932188 -0.007028
# 2020-02-25  21100  22163  20631  22089  3474313  0.049309

# %%
stock['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# - 비트코인

# %%
stock = fdr.DataReader('BTC/USD', start)  #비트코인
stock.head()
# Out:
#                     Open          High          Low        Close    Adj Close  \
# Date
# 2020-02-19  10143.798828  10191.675781  9611.223633  9633.386719  9633.386719
# 2020-02-20   9629.325195   9643.216797  9507.900391  9608.475586  9608.475586
# 2020-02-21   9611.782227   9723.014648  9589.743164  9686.441406  9686.441406
# 2020-02-22   9687.707031   9698.231445  9600.728516  9663.181641  9663.181641
# 2020-02-23   9663.318359   9937.404297  9657.791016  9924.515625  9924.515625
#
#                  Volume
# Date
# 2020-02-19  46992019710
# 2020-02-20  44925260237
# 2020-02-21  40930547513
# 2020-02-22  35838025154
# 2020-02-23  41185185761

# %%
stock['Close'].plot()
# Out:
# <Axes: xlabel='Date'>
