# %%
# !pip install -q mpl_finance
# !pip install -q finance-datareader
# !pip install -q pandas_datareader

# %%
import pandas_datareader as data_reader
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
import os
import shutil
import multiprocessing
from mpl_finance import candlestick_ohlc

# %% [markdown]
# ## Candle Chart image file 생성

# %%
df = pd.read_csv("data/stockcode.csv", index_col=0, encoding="cp949")
print(df.shape)
df.head()
# Out:
# (5646, 4)
#      code code_name  smarket  kospi200
# 0  000020      동화약품        0         0
# 1  000030      우리은행        0         1
# 2  000040     KR모터스        0         0
# 3  000050        경방        0         0
# 4  000060     메리츠화재        0         0

# %%
df.smarket.value_counts()
# Out:
# 3     2480
# 0     1489
# 10    1284
# 8      393
# Name: smarket, dtype: int64

# %%
df_smarket = df[(df.smarket == 0) | (df.smarket == 10)]
print(df_smarket.shape)
df_smarket.head()
# Out:
# (2773, 4)
#      code code_name  smarket  kospi200
# 0  000020      동화약품        0         0
# 1  000030      우리은행        0         1
# 2  000040     KR모터스        0         0
# 3  000050        경방        0         0
# 4  000060     메리츠화재        0         0

# %%
# tickers = df[df['kospi200'] == 1]['code'].values
tickers = df_smarket['code'].values

# %%
n1 = int(np.floor(len(tickers)*0.7))
n2 = int(np.floor(len(tickers)*0.2))
n3 = int(np.floor(len(tickers)*0.1))
n1, n2, n3
# Out:
# (1941, 554, 277)

# %%
train, val, test = tickers[:n1], tickers[n1:n1+n2], tickers[n1+n2:]
train
# Out:
# array(['000020', '000030', '000040', ..., '052710', '052770', '052790'],
#       dtype=object)

# %%
# tmp = "/Users/ohyoungjea/Downloads/"

tmp = "C:\\Users\\trimu\\Downloads\\"

os.mkdir(tmp+"\\candles")
for path in [tmp+"candles\\train", tmp+"candles\\val", tmp+"candles\\test"]:
    try:
        shutil.rmtree(path)
    except:
        pass
    os.mkdir(path)
    os.mkdir(path+"\\ups")
    os.mkdir(path+"\\downs")
    os.mkdir(path+"\\flats")

# %%
def image_creation(ticker, up_ratio, down_ratio, window=180, future=7, print_y=False):
    plt.rcParams.update({'figure.max_open_warning': 0})
    
    df = fdr.DataReader(ticker)
    df['MA6'] = df['Close'].rolling(6).mean()
    df['MA20'] = df['Close'].rolling(20).mean()

    start_idx = 0
    seq = 0

    while start_idx+window+future < df.shape[0]:
        sec = df.loc[df.index[start_idx]:df.index[start_idx+window+future]]
        sec.reset_index(inplace=True)

        seq += 1

        last_price = \
            sec.loc[sec.index[0]:sec.index[window]].tail(1)['Close'].values[0]

        future_price = sec.loc[sec.index[window+future]]['Close'] 

        fig, ax = plt.subplots(1, 1, figsize=(6, 4))

        x = np.arange(len(sec.index))
        ohlc = sec[['Open', 'High', 'Low', 'Close']].astype(int).values
        dohlc = np.hstack((np.reshape(x, (-1, 1)), ohlc))
        # 봉차트
        candlestick_ohlc(ax, dohlc, width=0.5, colorup='r', colordown='b')
        # 이동 평균
        sec.MA6.plot(ax=ax)
        sec.MA20.plot(ax=ax)

        plt.xticks([])
        plt.yticks([])

        if future_price > last_price * up_ratio:
            plt.savefig(f'{path}\\ups\\{ticker}{seq}.png')
            if print_y:
                print(f'{path}\\ups\\{ticker}{seq}.png....last',
                  f'last price={last_price}, future price={future_price}')
        elif future_price < last_price * down_ratio:
            plt.savefig(f'{path}\\downs\\{ticker}{seq}.png')
            if print_y:
                print(f'{path}\\downs\\{ticker}{seq}.png....',
                  f'last price={last_price}, future price={future_price}')
        else:
            plt.savefig(f'{path}\\flats\\{ticker}{seq}.png')
            if print_y:
                print(f'{path}\\flats\\{ticker}{seq}.png....',
                  f'last price={last_price}, future price={future_price}')

        plt.close()   

        start_idx += window

    print(f"processing {ticker} completed...seq#: {seq}", f"elapse time: {(time.time() - s)/60:.2f} mins"))

# %%
LAST_PROCESSED_CODE = '009290'  # Restart from here

# %%
up_ratio = 1.03    # 3
down_ratio = 0.97  # 3% 하락

s = time.time()

for tickers, folder in zip([train, val, test], ["train", "val", "test"]):
    path = tmp+"candles\\" + folder
    
    for ticker in tickers:
        if ticker > LAST_PROCESSED_CODE:
            image_creation(ticker, up_ratio, down_ratio, window=180, future=7, print_y=False)
        
print(f"Total elapse time: {(time.time() - s)/60:.2f} mins")
# Out:
# processing 000020 completed...seq#: 33
# processing 000030 completed...seq#: 5
# processing 000040 completed...seq#: 33
# processing 000050 completed...seq#: 33
# processing 000060 completed...seq#: 33
# processing 000070 completed...seq#: 33
# processing 000075 completed...seq#: 33
# processing 000080 completed...seq#: 16
# processing 000087 completed...seq#: 13
# processing 000100 completed...seq#: 33
# processing 000105 completed...seq#: 33
# processing 000120 completed...seq#: 33
# processing 000140 completed...seq#: 33
# processing 000145 completed...seq#: 33
# processing 000150 completed...seq#: 33
# processing 000155 completed...seq#: 33
# processing 000157 completed...seq#: 30
# processing 000180 completed...seq#: 33
# processing 000210 completed...seq#: 33
# processing 000215 completed...seq#: 33
# processing 000220 completed...seq#: 33
# processing 000225 completed...seq#: 33
# processing 000227 completed...seq#: 29
# processing 000230 completed...seq#: 33
# processing 000240 completed...seq#: 33
# processing 000270 completed...seq#: 33
# processing 000300 completed...seq#: 33
# processing 000320 completed...seq#: 33
# processing 000325 completed...seq#: 33
# processing 000370 completed...seq#: 33
# processing 000390 completed...seq#: 33
# processing 000400 completed...seq#: 33
# processing 000430 completed...seq#: 33
# processing 000480 completed...seq#: 33
# processing 000490 completed...seq#: 33
# processing 000500 completed...seq#: 33
# processing 000520 completed...seq#: 33
# processing 000540 completed...seq#: 33
# processing 000545 completed...seq#: 33
# processing 000547 completed...seq#: 30
# processing 000590 completed...seq#: 33
# processing 000640 completed...seq#: 33
# processing 000650 completed...seq#: 33
# processing 000660 completed...seq#: 33
# processing 000670 completed...seq#: 33
# processing 000680 completed...seq#: 33
# processing 000700 completed...seq#: 33
# processing 000720 completed...seq#: 33
# processing 000725 completed...seq#: 33
# processing 000760 completed...seq#: 33
# processing 000810 completed...seq#: 33
# processing 000815 completed...seq#: 33
# processing 000850 completed...seq#: 30
# processing 000860 completed...seq#: 33
# processing 000880 completed...seq#: 33
# processing 000885 completed...seq#: 33
# processing 00088K completed...seq#: 6
# processing 000890 completed...seq#: 33
# processing 000910 completed...seq#: 33
# processing 000950 completed...seq#: 33
# processing 000970 completed...seq#: 33
# processing 000990 completed...seq#: 33
# processing 000995 completed...seq#: 19
# processing 001020 completed...seq#: 33
# processing 001040 completed...seq#: 33
# processing 001045 completed...seq#: 33
# processing 001060 completed...seq#: 33
# processing 001065 completed...seq#: 33
# processing 001067 completed...seq#: 31
# processing 001070 completed...seq#: 33
# processing 001080 completed...seq#: 33
# processing 001120 completed...seq#: 33
# processing 001130 completed...seq#: 33
# processing 001140 completed...seq#: 33
# processing 001200 completed...seq#: 33
# processing 001210 completed...seq#: 33
# processing 001230 completed...seq#: 33
# processing 001250 completed...seq#: 33
# processing 001260 completed...seq#: 33
# processing 001270 completed...seq#: 33
# processing 001275 completed...seq#: 33
# processing 001290 completed...seq#: 33
# processing 001340 completed...seq#: 33
# processing 001360 completed...seq#: 33
# processing 001380 completed...seq#: 33
# processing 001390 completed...seq#: 33
# processing 001420 completed...seq#: 33
# processing 001430 completed...seq#: 33
# processing 001440 completed...seq#: 33
# processing 001450 completed...seq#: 33
# processing 001460 completed...seq#: 33
# processing 001465 completed...seq#: 33
# processing 001470 completed...seq#: 33
# processing 001500 completed...seq#: 33
# processing 001510 completed...seq#: 33
# processing 001515 completed...seq#: 33
# processing 001520 completed...seq#: 33
# processing 001525 completed...seq#: 33
# processing 001527 completed...seq#: 31
# processing 001529 completed...seq#: 19
# processing 001530 completed...seq#: 33
# processing 001550 completed...seq#: 33
# processing 001560 completed...seq#: 21
# processing 001570 completed...seq#: 33
# processing 001620 completed...seq#: 33
# processing 001630 completed...seq#: 33
# processing 001680 completed...seq#: 33
# processing 001685 completed...seq#: 33
# processing 001720 completed...seq#: 33
# processing 001725 completed...seq#: 33
# processing 001740 completed...seq#: 33
# processing 001745 completed...seq#: 33
# processing 001750 completed...seq#: 33
# processing 001755 completed...seq#: 33
# processing 001770 completed...seq#: 33
# processing 001780 completed...seq#: 33
# processing 001790 completed...seq#: 33
# processing 001795 completed...seq#: 33
# processing 001799 completed...seq#: 13
# processing 001800 completed...seq#: 33
# processing 001820 completed...seq#: 33
# processing 001880 completed...seq#: 33
# processing 001940 completed...seq#: 33
# processing 002000 completed...seq#: 33
# processing 002005 completed...seq#: 33
# processing 002020 completed...seq#: 33
# processing 002025 completed...seq#: 33
# processing 002030 completed...seq#: 33
# processing 002070 completed...seq#: 33
# processing 002100 completed...seq#: 33
# processing 002140 completed...seq#: 33
# processing 002150 completed...seq#: 15
# processing 002170 completed...seq#: 33
# processing 002200 completed...seq#: 33
# processing 002210 completed...seq#: 33
# processing 002220 completed...seq#: 33
# processing 002240 completed...seq#: 33
# processing 002250 completed...seq#: 33
# processing 002270 completed...seq#: 33
# processing 002300 completed...seq#: 33
# processing 002310 completed...seq#: 33
# processing 002320 completed...seq#: 33
# processing 002350 completed...seq#: 33
# processing 002355 completed...seq#: 30
# processing 002360 completed...seq#: 33
# processing 002380 completed...seq#: 33
# processing 002390 completed...seq#: 33
# processing 002410 completed...seq#: 33
# processing 002420 completed...seq#: 33
# processing 002450 completed...seq#: 33
# processing 002460 completed...seq#: 33
# processing 002600 completed...seq#: 33
# processing 002620 completed...seq#: 33
# processing 002630 completed...seq#: 33
# processing 002690 completed...seq#: 8
# processing 002700 completed...seq#: 33
# processing 002710 completed...seq#: 33
# processing 002720 completed...seq#: 33
# processing 002760 completed...seq#: 33
# processing 002780 completed...seq#: 33
# processing 002785 completed...seq#: 25
# processing 002787 completed...seq#: 20
# processing 002790 completed...seq#: 33
# processing 002795 completed...seq#: 33
# processing 002810 completed...seq#: 33
# processing 002820 completed...seq#: 33
# processing 002840 completed...seq#: 33
# processing 002870 completed...seq#: 33
# processing 002880 completed...seq#: 33
# processing 002900 completed...seq#: 33
# processing 002920 completed...seq#: 33
# processing 002960 completed...seq#: 33
# processing 002990 completed...seq#: 33
# processing 002995 completed...seq#: 33
# processing 003000 completed...seq#: 33
# processing 003010 completed...seq#: 33
# processing 003030 completed...seq#: 33
# processing 003060 completed...seq#: 33
# processing 003070 completed...seq#: 33
# processing 003075 completed...seq#: 33
# processing 003080 completed...seq#: 33
# processing 003090 completed...seq#: 33
# processing 003120 completed...seq#: 33
# processing 003160 completed...seq#: 33
# processing 003200 completed...seq#: 33
# processing 003220 completed...seq#: 32
# processing 003230 completed...seq#: 33
# processing 003240 completed...seq#: 33
# processing 003280 completed...seq#: 33
# processing 003300 completed...seq#: 33
# processing 003350 completed...seq#: 33
# processing 003410 completed...seq#: 33
# processing 003415 completed...seq#: 33
# processing 003460 completed...seq#: 33
# processing 003465 completed...seq#: 33
# processing 003470 completed...seq#: 33
# processing 003475 completed...seq#: 33
# processing 003480 completed...seq#: 33
# processing 003490 completed...seq#: 33
# processing 003495 completed...seq#: 33
# processing 003520 completed...seq#: 33
# processing 003530 completed...seq#: 33
# processing 003535 completed...seq#: 33
# processing 003540 completed...seq#: 33
# processing 003545 completed...seq#: 33
# processing 003547 completed...seq#: 19
# processing 003550 completed...seq#: 33
# processing 003555 completed...seq#: 33
# processing 003560 completed...seq#: 33
# processing 003570 completed...seq#: 33
# processing 003580 completed...seq#: 33
# processing 003610 completed...seq#: 33
# processing 003620 completed...seq#: 33
# processing 003650 completed...seq#: 33
# processing 003680 completed...seq#: 33
# processing 003690 completed...seq#: 33
# processing 003720 completed...seq#: 33
# processing 003780 completed...seq#: 33
# processing 003830 completed...seq#: 33
# processing 003850 completed...seq#: 33
# processing 003920 completed...seq#: 33
# processing 003925 completed...seq#: 33
# processing 003960 completed...seq#: 33
# processing 004000 completed...seq#: 33
# processing 004020 completed...seq#: 33
# processing 004060 completed...seq#: 33
# processing 004080 completed...seq#: 33
# processing 004090 completed...seq#: 33
# processing 004100 completed...seq#: 33
# processing 004105 completed...seq#: 33
# processing 004130 completed...seq#: 33
# processing 004135 completed...seq#: 33
# processing 004140 completed...seq#: 33
# processing 004150 completed...seq#: 33
# processing 004170 completed...seq#: 33
# processing 004200 completed...seq#: 33
# processing 004250 completed...seq#: 33
# processing 004255 completed...seq#: 33
# processing 004270 completed...seq#: 33
# processing 004310 completed...seq#: 33
# processing 004360 completed...seq#: 33
# processing 004365 completed...seq#: 33
# processing 004370 completed...seq#: 33
# processing 004380 completed...seq#: 33
# processing 004410 completed...seq#: 33
# processing 004415 completed...seq#: 33
# processing 004430 completed...seq#: 33
# processing 004440 completed...seq#: 7
# processing 004450 completed...seq#: 33
# processing 004490 completed...seq#: 33
# processing 004540 completed...seq#: 33
# processing 004545 completed...seq#: 33
# processing 004560 completed...seq#: 33
# processing 004565 completed...seq#: 33
# processing 004690 completed...seq#: 33
# processing 004700 completed...seq#: 33
# processing 004710 completed...seq#: 33
# processing 004720 completed...seq#: 33
# processing 004770 completed...seq#: 33
# processing 004800 completed...seq#: 33
# processing 004830 completed...seq#: 33
# processing 004835 completed...seq#: 33
# processing 004840 completed...seq#: 33
# processing 004870 completed...seq#: 33
# processing 004890 completed...seq#: 22
# processing 004910 completed...seq#: 33
# processing 004920 completed...seq#: 33
# processing 004960 completed...seq#: 33
# processing 004970 completed...seq#: 33
# processing 004980 completed...seq#: 33
# processing 004985 completed...seq#: 33
# processing 004987 completed...seq#: 27
# processing 004989 completed...seq#: 25
# processing 004990 completed...seq#: 33
# processing 00499K completed...seq#: 5
# processing 005010 completed...seq#: 33
# processing 005030 completed...seq#: 33
# processing 005070 completed...seq#: 33
# processing 005090 completed...seq#: 33
# processing 005110 completed...seq#: 33
# processing 005180 completed...seq#: 33
# processing 005190 completed...seq#: 33
# processing 005250 completed...seq#: 33
# processing 005257 completed...seq#: 33
# processing 005300 completed...seq#: 33
# processing 005305 completed...seq#: 33
# processing 005320 completed...seq#: 33
# processing 005360 completed...seq#: 33
# processing 005380 completed...seq#: 33
# processing 005385 completed...seq#: 33
# processing 005387 completed...seq#: 31
# processing 005389 completed...seq#: 30
# processing 005390 completed...seq#: 33
# processing 005420 completed...seq#: 33
# processing 005430 completed...seq#: 33
# processing 005440 completed...seq#: 33
# processing 005450 completed...seq#: 33
# processing 005490 completed...seq#: 33
# processing 005500 completed...seq#: 33
# processing 005610 completed...seq#: 33
# processing 005680 completed...seq#: 33
# processing 005690 completed...seq#: 33
# processing 005720 completed...seq#: 33
# processing 005725 completed...seq#: 33
# processing 005740 completed...seq#: 33
# processing 005745 completed...seq#: 33
# processing 005750 completed...seq#: 33
# processing 005800 completed...seq#: 33
# processing 005810 completed...seq#: 33
# processing 005820 completed...seq#: 33
# processing 005830 completed...seq#: 33
# processing 005850 completed...seq#: 33
# processing 005870 completed...seq#: 33
# processing 005880 completed...seq#: 33
# processing 005930 completed...seq#: 33
# processing 005935 completed...seq#: 33
# processing 005940 completed...seq#: 33
# processing 005945 completed...seq#: 33
# processing 005950 completed...seq#: 33
# processing 005960 completed...seq#: 33
# processing 005965 completed...seq#: 33
# processing 005980 completed...seq#: 33
# processing 006040 completed...seq#: 33
# processing 006060 completed...seq#: 33
# processing 006090 completed...seq#: 33
# processing 006110 completed...seq#: 33
# processing 006120 completed...seq#: 33
# processing 006125 completed...seq#: 33
# processing 006200 completed...seq#: 33
# processing 006220 completed...seq#: 33
# processing 006260 completed...seq#: 33
# processing 006280 completed...seq#: 33
# processing 006340 completed...seq#: 33
# processing 006345 completed...seq#: 33
# processing 006360 completed...seq#: 33
# processing 006370 completed...seq#: 33
# processing 006380 completed...seq#: 33
# processing 006390 completed...seq#: 33
# processing 006400 completed...seq#: 33
# processing 006405 completed...seq#: 33
# processing 006490 completed...seq#: 33
# processing 006570 completed...seq#: 33
# processing 006650 completed...seq#: 30
# processing 006660 completed...seq#: 33
# processing 006740 completed...seq#: 33
# processing 006800 completed...seq#: 33
# processing 006805 completed...seq#: 33
# processing 00680K completed...seq#: 4
# processing 006840 completed...seq#: 30
# processing 006880 completed...seq#: 10
# processing 006890 completed...seq#: 32
# processing 006980 completed...seq#: 33
# processing 007070 completed...seq#: 13
# processing 007110 completed...seq#: 33
# processing 007120 completed...seq#: 32
# processing 007160 completed...seq#: 33
# processing 007210 completed...seq#: 33
# processing 007280 completed...seq#: 33
# processing 007310 completed...seq#: 33
# processing 007340 completed...seq#: 33
# processing 007460 completed...seq#: 33
# processing 007540 completed...seq#: 33
# processing 007570 completed...seq#: 33
# processing 007575 completed...seq#: 33
# processing 007590 completed...seq#: 33
# processing 007610 completed...seq#: 33
# processing 007630 completed...seq#: 33
# processing 007660 completed...seq#: 29
# processing 007690 completed...seq#: 33
# processing 007700 completed...seq#: 33
# processing 007810 completed...seq#: 33
# processing 007815 completed...seq#: 33
# processing 00781K completed...seq#: 11
# processing 007860 completed...seq#: 33
# processing 007980 completed...seq#: 33
# processing 008040 completed...seq#: 33
# processing 008060 completed...seq#: 33
# processing 008110 completed...seq#: 33
# processing 008250 completed...seq#: 33
# processing 008260 completed...seq#: 33
# processing 008350 completed...seq#: 33
# processing 008355 completed...seq#: 33
# processing 008420 completed...seq#: 33
# processing 008490 completed...seq#: 33
# processing 008500 completed...seq#: 33
# processing 008560 completed...seq#: 33
# processing 008600 completed...seq#: 33
# processing 008700 completed...seq#: 33
# processing 008730 completed...seq#: 33
# processing 008770 completed...seq#: 33
# processing 008775 completed...seq#: 33
# processing 008870 completed...seq#: 33
# processing 008930 completed...seq#: 33
# processing 008970 completed...seq#: 33
# processing 009070 completed...seq#: 33
# processing 009140 completed...seq#: 33
# processing 009150 completed...seq#: 33
# processing 009155 completed...seq#: 33
# processing 009160 completed...seq#: 33
# processing 009180 completed...seq#: 33
# processing 009190 completed...seq#: 33
# processing 009200 completed...seq#: 33
# processing 009240 completed...seq#: 26
# processing 009270 completed...seq#: 33
# processing 009275 completed...seq#: 33
# processing 009290 completed...seq#: 33

# %%
for path in [tmp+"candles\\train\\", tmp+"candles\\val\\", tmp+"candles\\test\\"]:
    for subpath in ['ups', 'downs', 'flats']:
        print(path+subpath, len(os.listdir(path + subpath)))
